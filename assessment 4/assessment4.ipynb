# %% [markdown]
# # Question 4: Sum of Digits of a Three-Digit Number

# %%
# take a three-digit number as input 
n = int(input("Enter a three digit number: "))
print("Sum of digits:", n // 100 + n // 10 % 10 + n % 10)
# Out:
# Sum of digits: 12
