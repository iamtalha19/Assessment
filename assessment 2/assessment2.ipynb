# %% [markdown]
# # Python programming

# %% [markdown]
# ## Task 1: Print a message to the console

# %%
print("Hello, everyone! I am learning Python. 😄")

# %% [markdown]
# ## Task 2: Declare variables and print them

# %%
name = "Talha"
age = 22
animal = "dog"
print("Name:", name)
print("Age:", age)
print("Favorite Animal:", animal)

# %% [markdown]
# ## Task 3: Print all variables in one line

# %%
print("My name is",name,",I am",age,"years old, and I love",animal,".",)

# %% [markdown]
# ## Task 4: Play with different data types

# %%
movie = "Spider-Man"
birthyear = 2003
snack = 50.50
print("Favorite movie:", movie)
print("Birth Year:", birthyear)
print("Price of Snack:", snack)

# %% [markdown]
# ## Task 5: Your Favorite Hobby

# %%
hobby = "reading books"
print("My favorite hobby is", hobby)
